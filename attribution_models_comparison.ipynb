# %%
import pandas as pd

# %% [markdown]
# # Goal

# %% [markdown]
#  This notebook aims to compare 3 different attribution models applied to the dataset 'homepage_visits.csv'. The models are First-Touch, Last-Touch and Linear.
#
#  All the models have similar results for this dataset, so the recommendation is to proceeed with Last-Touch attribution for being simple and widely adopted by the industry.

# %% [markdown]
# # Data Preparation

# %%
# Load the data
df = pd.read_csv('homepage_visits.csv')

# %%
df
# Out:
#                        EVENT_DATETIME    VISITOR_ID ACQUISITION_CHANNEL
# 0       2021-10-19 08:40:21.204000000  385685697470           channel_8
# 1       2021-10-30 11:37:24.650000000  490063861180           channel_4
# 2       2021-10-29 18:29:08.754000000  489723674348           channel_4
# 3       2021-10-02 21:17:11.035000000  473638768926           channel_1
# 4       2021-10-16 07:11:35.390000000  480995855292           channel_4
# ...                               ...           ...                 ...
# 251457  2021-10-03 02:57:21.317000000  473744387526           channel_8
# 251458  2021-10-27 07:42:56.317000000  488328212466           channel_1
# 251459  2021-10-20 04:40:34.164000000  483285124336           channel_1
# 251460  2021-10-10 19:50:51.873000000  477883496040           channel_4
# 251461  2021-10-20 00:06:00.782000000  483161044910           channel_4
#
# [251462 rows x 3 columns]

# %%
# Convert EVENT_DATETIME to datetime object for easier manipulation
df['EVENT_DATETIME'] = pd.to_datetime(df['EVENT_DATETIME'])

# Sort by VISITOR_ID and EVENT_DATETIME to simulate the journey per visitor
df = df.sort_values(by=['VISITOR_ID', 'EVENT_DATETIME'])

# %%
# Group by VISITOR_ID to get first-touch and last-touch attribution models
def attribution_model(df, model='last_touch'):
    # Create a dataframe to store attribution results
    attribution_df = pd.DataFrame(columns=['VISITOR_ID', 'ATTRIBUTION_CHANNEL'])

    if model == 'last_touch':
        # Take the last channel for each visitor
        attribution_df = df.groupby('VISITOR_ID').tail(1)[['VISITOR_ID', 'ACQUISITION_CHANNEL']].copy()
        attribution_df.rename(columns={'ACQUISITION_CHANNEL': 'ATTRIBUTION_CHANNEL'}, inplace=True)
    elif model == 'first_touch':
        # Take the first channel for each visitor
        attribution_df = df.groupby('VISITOR_ID').head(1)[['VISITOR_ID', 'ACQUISITION_CHANNEL']].copy()
        attribution_df.rename(columns={'ACQUISITION_CHANNEL': 'ATTRIBUTION_CHANNEL'}, inplace=True)

    return attribution_df

# %%
# Applying last-touch attribution
last_touch_df = attribution_model(df, model='last_touch')

# Applying first-touch attribution
first_touch_df = attribution_model(df, model='first_touch')

# Analyze the results, for example, by counting occurrences of each channel
last_touch_counts = last_touch_df['ATTRIBUTION_CHANNEL'].value_counts()
first_touch_counts = first_touch_df['ATTRIBUTION_CHANNEL'].value_counts()

# %%
# Create the linear attribution model
def linear_attribution(df):
    # Group by VISITOR_ID to find all channels a visitor touched
    grouped = df.groupby('VISITOR_ID')
    
    # Create a list to store the attribution results
    attribution_records = []

    # For each visitor, find their unique acquisition channels
    for visitor_id, group in grouped:
        unique_channels = group['ACQUISITION_CHANNEL'].unique()
        credit_per_channel = 1 / len(unique_channels)  # Equal credit for all channels

        # Assign credit to each channel and store it in the list
        for channel in unique_channels:
            attribution_records.append({'ACQUISITION_CHANNEL': channel,
                                        'ATTRIBUTION_CREDIT': credit_per_channel})
    
    # Convert the list of records to a DataFrame
    attribution_df = pd.DataFrame(attribution_records)
    
    # Aggregate the attribution credits per channel
    total_attribution = attribution_df.groupby('ACQUISITION_CHANNEL')['ATTRIBUTION_CREDIT'].sum().reset_index()

    return total_attribution

# %%
# Apply the linear attribution model
linear_attribution_df = linear_attribution(df)

# %%
## Combine the models in one dataframe ##

# # First, convert the first_touch_counts and last_touch_counts into DataFrames for merging
first_touch_df = first_touch_counts.reset_index()
first_touch_df.columns = ['ACQUISITION_CHANNEL', 'FIRST_TOUCH_COUNT']

last_touch_df = last_touch_counts.reset_index()
last_touch_df.columns = ['ACQUISITION_CHANNEL', 'LAST_TOUCH_COUNT']

# Merge the three DataFrames: first_touch_df, last_touch_df, and linear_attribution_df
comparison_df = pd.merge(first_touch_df, last_touch_df, on='ACQUISITION_CHANNEL', how='outer')
comparison_df = pd.merge(comparison_df, linear_attribution_df, on='ACQUISITION_CHANNEL', how='outer')

# Fill any missing values with 0 (in case some channels are missing in one model)
comparison_df = comparison_df.fillna(0)

# Sorting by last touch for easier viewing, you can change this sorting criteria
comparison_df = comparison_df.sort_values(by='LAST_TOUCH_COUNT', ascending=False)

# %% [markdown]
# # Results

# %%
# Styling the comparison DataFrame
styled_df = comparison_df[["ACQUISITION_CHANNEL","FIRST_TOUCH_COUNT","LAST_TOUCH_COUNT","ATTRIBUTION_CREDIT"]].style.hide_index()\
    .bar(subset=['FIRST_TOUCH_COUNT'], color="#63eb80", align='mid')\
    .bar(subset=['LAST_TOUCH_COUNT'], color="#0569ff", align='mid')\
    .bar(subset=['ATTRIBUTION_CREDIT'], color='#55d794', align='mid')\
    .format(precision=0, thousands=',', formatter={
        'FIRST_TOUCH_COUNT': "{:.0f}",
        'LAST_TOUCH_COUNT': "{:.0f}",
        'ATTRIBUTION_CREDIT': "{:.2f}"
    })

# Display the styled DataFrame
styled_df
# Out:
# /var/folders/kf/dtw20yc53tl93ynyrp08thnh0000gn/T/ipykernel_49903/2053498809.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   styled_df = comparison_df[["ACQUISITION_CHANNEL","FIRST_TOUCH_COUNT","LAST_TOUCH_COUNT","ATTRIBUTION_CREDIT"]].style.hide_index()\
# <style type="text/css">
# #T_542d7_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 100.0%, transparent 100.0%);
# }
# #T_542d7_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 100.0%, transparent 100.0%);
# }
# #T_542d7_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 100.0%, transparent 100.0%);
# }
# #T_542d7_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 92.6%, transparent 92.6%);
# }
# #T_542d7_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 88.0%, transparent 88.0%);
# }
# #T_542d7_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 89.8%, transparent 89.8%);
# }
# #T_542d7_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 31.2%, transparent 31.2%);
# }
# #T_542d7_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 39.7%, transparent 39.7%);
# }
# #T_542d7_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 35.9%, transparent 35.9%);
# }
# #T_542d7_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 22.6%, transparent 22.6%);
# }
# #T_542d7_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 19.4%, transparent 19.4%);
# }
# #T_542d7_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 20.7%, transparent 20.7%);
# }
# #T_542d7_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 5.4%, transparent 5.4%);
# }
# #T_542d7_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 10.4%, transparent 10.4%);
# }
# #T_542d7_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 8.8%, transparent 8.8%);
# }
# #T_542d7_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 4.4%, transparent 4.4%);
# }
# #T_542d7_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 5.0%, transparent 5.0%);
# }
# #T_542d7_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 4.6%, transparent 4.6%);
# }
# #T_542d7_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 2.6%, transparent 2.6%);
# }
# #T_542d7_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 2.3%, transparent 2.3%);
# }
# #T_542d7_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 2.5%, transparent 2.5%);
# }
# #T_542d7_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 0.8%, transparent 0.8%);
# }
# #T_542d7_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 0.7%, transparent 0.7%);
# }
# #T_542d7_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 0.8%, transparent 0.8%);
# }
# #T_542d7_row8_col1, #T_542d7_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 0.4%, transparent 0.4%);
# }
# #T_542d7_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 0.4%, transparent 0.4%);
# }
# #T_542d7_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 0.4%, transparent 0.4%);
# }
# #T_542d7_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 0.3%, transparent 0.3%);
# }
# #T_542d7_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 0.3%, transparent 0.3%);
# }
# </style>
# <table id="T_542d7">
#   <thead>
#     <tr>
#       <th id="T_542d7_level0_col0" class="col_heading level0 col0" >ACQUISITION_CHANNEL</th>
#       <th id="T_542d7_level0_col1" class="col_heading level0 col1" >FIRST_TOUCH_COUNT</th>
#       <th id="T_542d7_level0_col2" class="col_heading level0 col2" >LAST_TOUCH_COUNT</th>
#       <th id="T_542d7_level0_col3" class="col_heading level0 col3" >ATTRIBUTION_CREDIT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_542d7_row0_col0" class="data row0 col0" >channel_1</td>
#       <td id="T_542d7_row0_col1" class="data row0 col1" >57640</td>
#       <td id="T_542d7_row0_col2" class="data row0 col2" >56360</td>
#       <td id="T_542d7_row0_col3" class="data row0 col3" >56893.87</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row1_col0" class="data row1 col0" >channel_4</td>
#       <td id="T_542d7_row1_col1" class="data row1 col1" >53347</td>
#       <td id="T_542d7_row1_col2" class="data row1 col2" >49587</td>
#       <td id="T_542d7_row1_col3" class="data row1 col3" >51091.80</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row2_col0" class="data row2 col0" >channel_8</td>
#       <td id="T_542d7_row2_col1" class="data row2 col1" >17974</td>
#       <td id="T_542d7_row2_col2" class="data row2 col2" >22372</td>
#       <td id="T_542d7_row2_col3" class="data row2 col3" >20409.77</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row3_col0" class="data row3 col0" >channel_2</td>
#       <td id="T_542d7_row3_col1" class="data row3 col1" >13046</td>
#       <td id="T_542d7_row3_col2" class="data row3 col2" >10930</td>
#       <td id="T_542d7_row3_col3" class="data row3 col3" >11797.82</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row4_col0" class="data row4 col0" >channel_11</td>
#       <td id="T_542d7_row4_col1" class="data row4 col1" >3138</td>
#       <td id="T_542d7_row4_col2" class="data row4 col2" >5881</td>
#       <td id="T_542d7_row4_col3" class="data row4 col3" >4984.82</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row5_col0" class="data row5 col0" >channel_3</td>
#       <td id="T_542d7_row5_col1" class="data row5 col1" >2539</td>
#       <td id="T_542d7_row5_col2" class="data row5 col2" >2836</td>
#       <td id="T_542d7_row5_col3" class="data row5 col3" >2641.77</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row6_col0" class="data row6 col0" >channel_6</td>
#       <td id="T_542d7_row6_col1" class="data row6 col1" >1494</td>
#       <td id="T_542d7_row6_col2" class="data row6 col2" >1292</td>
#       <td id="T_542d7_row6_col3" class="data row6 col3" >1400.47</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row7_col0" class="data row7 col0" >channel_5</td>
#       <td id="T_542d7_row7_col1" class="data row7 col1" >457</td>
#       <td id="T_542d7_row7_col2" class="data row7 col2" >410</td>
#       <td id="T_542d7_row7_col3" class="data row7 col3" >431.63</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row8_col0" class="data row8 col0" >channel_10</td>
#       <td id="T_542d7_row8_col1" class="data row8 col1" >224</td>
#       <td id="T_542d7_row8_col2" class="data row8 col2" >246</td>
#       <td id="T_542d7_row8_col3" class="data row8 col3" >239.37</td>
#     </tr>
#     <tr>
#       <td id="T_542d7_row9_col0" class="data row9 col0" >channel_7</td>
#       <td id="T_542d7_row9_col1" class="data row9 col1" >219</td>
#       <td id="T_542d7_row9_col2" class="data row9 col2" >164</td>
#       <td id="T_542d7_row9_col3" class="data row9 col3" >186.70</td>
#     </tr>
#   </tbody>
# </table>

# %%
# First, calculate total counts/credits for each model
total_first_touch = comparison_df['FIRST_TOUCH_COUNT'].sum()
total_last_touch = comparison_df['LAST_TOUCH_COUNT'].sum()
total_linear_credit = comparison_df['ATTRIBUTION_CREDIT'].sum()

# Add new columns to the DataFrame for percentages
comparison_df['FIRST_TOUCH_PERCENT'] = (comparison_df['FIRST_TOUCH_COUNT'] / total_first_touch) * 100
comparison_df['LAST_TOUCH_PERCENT'] = (comparison_df['LAST_TOUCH_COUNT'] / total_last_touch) * 100
comparison_df['LINEAR_ATTRIBUTION_PERCENT'] = (comparison_df['ATTRIBUTION_CREDIT'] / total_linear_credit) * 100

# Now apply styling to the percentage columns
styled_df = comparison_df[["ACQUISITION_CHANNEL","FIRST_TOUCH_PERCENT","LAST_TOUCH_PERCENT","LINEAR_ATTRIBUTION_PERCENT"]].style.hide_index()\
    .bar(subset=['FIRST_TOUCH_PERCENT'], color="#63eb80", align='mid')\
    .bar(subset=['LAST_TOUCH_PERCENT'], color="#0569ff", align='mid')\
    .bar(subset=['LINEAR_ATTRIBUTION_PERCENT'], color='#55d794', align='mid')\
    .format(precision=2, thousands=',', formatter={
        'FIRST_TOUCH_PERCENT': "{:.2f}%",
        'LAST_TOUCH_PERCENT': "{:.2f}%",
        'LINEAR_ATTRIBUTION_PERCENT': "{:.2f}%"
    })

# Display the styled DataFrame with percentages
styled_df
# Out:
# /var/folders/kf/dtw20yc53tl93ynyrp08thnh0000gn/T/ipykernel_49903/2058184642.py:12: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   styled_df = comparison_df[["ACQUISITION_CHANNEL","FIRST_TOUCH_PERCENT","LAST_TOUCH_PERCENT","LINEAR_ATTRIBUTION_PERCENT"]].style.hide_index()\
# <style type="text/css">
# #T_efd8c_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 100.0%, transparent 100.0%);
# }
# #T_efd8c_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 100.0%, transparent 100.0%);
# }
# #T_efd8c_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 100.0%, transparent 100.0%);
# }
# #T_efd8c_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 92.6%, transparent 92.6%);
# }
# #T_efd8c_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 88.0%, transparent 88.0%);
# }
# #T_efd8c_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 89.8%, transparent 89.8%);
# }
# #T_efd8c_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 31.2%, transparent 31.2%);
# }
# #T_efd8c_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 39.7%, transparent 39.7%);
# }
# #T_efd8c_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 35.9%, transparent 35.9%);
# }
# #T_efd8c_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 22.6%, transparent 22.6%);
# }
# #T_efd8c_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 19.4%, transparent 19.4%);
# }
# #T_efd8c_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 20.7%, transparent 20.7%);
# }
# #T_efd8c_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 5.4%, transparent 5.4%);
# }
# #T_efd8c_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 10.4%, transparent 10.4%);
# }
# #T_efd8c_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 8.8%, transparent 8.8%);
# }
# #T_efd8c_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 4.4%, transparent 4.4%);
# }
# #T_efd8c_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 5.0%, transparent 5.0%);
# }
# #T_efd8c_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 4.6%, transparent 4.6%);
# }
# #T_efd8c_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 2.6%, transparent 2.6%);
# }
# #T_efd8c_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 2.3%, transparent 2.3%);
# }
# #T_efd8c_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 2.5%, transparent 2.5%);
# }
# #T_efd8c_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 0.8%, transparent 0.8%);
# }
# #T_efd8c_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 0.7%, transparent 0.7%);
# }
# #T_efd8c_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 0.8%, transparent 0.8%);
# }
# #T_efd8c_row8_col1, #T_efd8c_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #63eb80 0.4%, transparent 0.4%);
# }
# #T_efd8c_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 0.4%, transparent 0.4%);
# }
# #T_efd8c_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 0.4%, transparent 0.4%);
# }
# #T_efd8c_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #0569ff 0.3%, transparent 0.3%);
# }
# #T_efd8c_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #55d794 0.3%, transparent 0.3%);
# }
# </style>
# <table id="T_efd8c">
#   <thead>
#     <tr>
#       <th id="T_efd8c_level0_col0" class="col_heading level0 col0" >ACQUISITION_CHANNEL</th>
#       <th id="T_efd8c_level0_col1" class="col_heading level0 col1" >FIRST_TOUCH_PERCENT</th>
#       <th id="T_efd8c_level0_col2" class="col_heading level0 col2" >LAST_TOUCH_PERCENT</th>
#       <th id="T_efd8c_level0_col3" class="col_heading level0 col3" >LINEAR_ATTRIBUTION_PERCENT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_efd8c_row0_col0" class="data row0 col0" >channel_1</td>
#       <td id="T_efd8c_row0_col1" class="data row0 col1" >38.41%</td>
#       <td id="T_efd8c_row0_col2" class="data row0 col2" >37.55%</td>
#       <td id="T_efd8c_row0_col3" class="data row0 col3" >37.91%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row1_col0" class="data row1 col0" >channel_4</td>
#       <td id="T_efd8c_row1_col1" class="data row1 col1" >35.55%</td>
#       <td id="T_efd8c_row1_col2" class="data row1 col2" >33.04%</td>
#       <td id="T_efd8c_row1_col3" class="data row1 col3" >34.04%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row2_col0" class="data row2 col0" >channel_8</td>
#       <td id="T_efd8c_row2_col1" class="data row2 col1" >11.98%</td>
#       <td id="T_efd8c_row2_col2" class="data row2 col2" >14.91%</td>
#       <td id="T_efd8c_row2_col3" class="data row2 col3" >13.60%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row3_col0" class="data row3 col0" >channel_2</td>
#       <td id="T_efd8c_row3_col1" class="data row3 col1" >8.69%</td>
#       <td id="T_efd8c_row3_col2" class="data row3 col2" >7.28%</td>
#       <td id="T_efd8c_row3_col3" class="data row3 col3" >7.86%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row4_col0" class="data row4 col0" >channel_11</td>
#       <td id="T_efd8c_row4_col1" class="data row4 col1" >2.09%</td>
#       <td id="T_efd8c_row4_col2" class="data row4 col2" >3.92%</td>
#       <td id="T_efd8c_row4_col3" class="data row4 col3" >3.32%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row5_col0" class="data row5 col0" >channel_3</td>
#       <td id="T_efd8c_row5_col1" class="data row5 col1" >1.69%</td>
#       <td id="T_efd8c_row5_col2" class="data row5 col2" >1.89%</td>
#       <td id="T_efd8c_row5_col3" class="data row5 col3" >1.76%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row6_col0" class="data row6 col0" >channel_6</td>
#       <td id="T_efd8c_row6_col1" class="data row6 col1" >1.00%</td>
#       <td id="T_efd8c_row6_col2" class="data row6 col2" >0.86%</td>
#       <td id="T_efd8c_row6_col3" class="data row6 col3" >0.93%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row7_col0" class="data row7 col0" >channel_5</td>
#       <td id="T_efd8c_row7_col1" class="data row7 col1" >0.30%</td>
#       <td id="T_efd8c_row7_col2" class="data row7 col2" >0.27%</td>
#       <td id="T_efd8c_row7_col3" class="data row7 col3" >0.29%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row8_col0" class="data row8 col0" >channel_10</td>
#       <td id="T_efd8c_row8_col1" class="data row8 col1" >0.15%</td>
#       <td id="T_efd8c_row8_col2" class="data row8 col2" >0.16%</td>
#       <td id="T_efd8c_row8_col3" class="data row8 col3" >0.16%</td>
#     </tr>
#     <tr>
#       <td id="T_efd8c_row9_col0" class="data row9 col0" >channel_7</td>
#       <td id="T_efd8c_row9_col1" class="data row9 col1" >0.15%</td>
#       <td id="T_efd8c_row9_col2" class="data row9 col2" >0.11%</td>
#       <td id="T_efd8c_row9_col3" class="data row9 col3" >0.12%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Analysis
#
# **Top Acquisition Channels**:
#
# - Channel 1 has the highest attribution credit (56,893.87), making it the dominant channel in the dataset.
# - Channel 4 follows closely behind with 51,091.80 in attribution credit.
#
#
# **Discrepancies Between First-Touch and Last-Touch**:
#
# - Channel 8 has a significant shift (+4,398) from first-touch to last-touch, indicating it is more effective at closing conversions rather than initiating them.
# - Channel 11 also shows a notable shift (+2,743), suggesting its role in finalizing conversions rather than early acquisition.
# - Channel 2 and Channel 1 are relatively stable, meaning their role in conversions is more balanced across the funnel.
#
# **First-Touch vs. Attribution Credit**:
#
# - Channels 1, 4, and 2 have higher first-touch counts than their attributed credit, meaning these channels may be good at generating initial traffic but could be losing conversions later.
# - Channels 8 and 11 have lower first-touch counts than their attribution credit, suggesting that they contribute more effectively in later-stage conversions.
#
# **Last-Touch vs. Attribution Credit**:
#
# - Channel 8 (+1,962) and Channel 11 (+896) have higher last-touch counts than their attribution credit, reinforcing their strong role in finalizing conversions.
# - Channel 1 (-533) and Channel 4 (-1,504) have lower last-touch counts compared to attribution, indicating that their impact might be spread across multiple touchpoints instead of acting as the final interaction.
#
# **Recommendations**:
#
# - Optimize Early-Stage Channels (Channel 1, Channel 4, Channel 2): These channels drive strong initial engagement, so focus on improving retention and conversion strategies.
# - Leverage Closing-Stage Channels (Channel 8, Channel 11): Since they perform well in the last touch, consider allocating budget for retargeting and remarketing campaigns.
# - Analyze Attribution Models Further: The discrepancy between first-touch, last-touch, and linear attribution suggests deeper funnel insights can be explored. It would be interesting to analyze user's journeys to complement the analysis.
